# %%
import pandas as pd

# %%
df = pd.read_excel("../mansoor/update_1.xlsx")

# %%
df.head()
# Out:
#    Time Time Code Country Name Country Code
# 0  1960    YR1960  Afghanistan          AFG  \
# 1  1970    YR1970  Afghanistan          AFG
# 2  1968    YR1968  Afghanistan          AFG
# 3  1971    YR1971  Afghanistan          AFG
# 4  2020    YR2020  Afghanistan          AFG
#
#   Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative) [SE.PRM.CUAT.FE.ZS]
# 0                                                                                                                    ..  \
# 1                                                                                                                   NaN
# 2                                                                                                                    ..
# 3                                                                                                                   NaN
# ...

# %%
# vertical_concat = pd.concat([df1, df2], axis=0)

# %%
# vertical_concat  = vertical_concat[['Time', 'Time Code', 'Country Name', 'Country Code']]

# %%
# vertical_concat=vertical_concat.dropna()
# vertical_concat=vertical_concat.dropna(axis=0)
# # Reset index after drop
# vertical_concat=vertical_concat.dropna().reset_index(drop=True)
# # Drop row that has all NaN values
# vertical_concat=vertical_concat.dropna(how='all')

# %%
df.columns
# Out:
# Index(['Time', 'Time Code', 'Country Name', 'Country Code',
#        'Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative) [SE.PRM.CUAT.FE.ZS]',
#        'Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative) [SE.SEC.CUAT.PO.ZS]',
#        'Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative) [SE.SEC.CUAT.UP.ZS]',
#        'Labor force, female [SL.TLF.TOTL.FE.IN]',
#        'Unemployment with intermediate education (% of total labor force with intermediate education) [SL.UEM.INTM.ZS]',
#        'Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]',
#        'GDP per capita (Current US$) [NY.GDP.PCAP.CD]',
#        'Services, value added (% of GDP) [NV.SRV.TOTL.ZS]',
#        'Manufacturing, value added (% of GDP) [NV.IND.MANF.ZS]'],
#       dtype='object')

# %%
df = df.sort_values(by=["Country Name", "Country Code"], ascending=True)

# %%
pd.options.display.max_colwidth = 1000

# %%
df.head()
# Out:
#    Time Time Code Country Name Country Code
# 0  1960    YR1960  Afghanistan          AFG  \
# 1  1970    YR1970  Afghanistan          AFG
# 2  1968    YR1968  Afghanistan          AFG
# 3  1971    YR1971  Afghanistan          AFG
# 4  2020    YR2020  Afghanistan          AFG
#
#   Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative) [SE.PRM.CUAT.FE.ZS]
# 0                                                                                                                    ..  \
# 1                                                                                                                   NaN
# 2                                                                                                                    ..
# 3                                                                                                                   NaN
# ...

# %%
df = df.drop_duplicates(subset=['Country Name', 'Time'], keep='first')

# %%
df.shape
# Out:
# (17073, 13)

# %%
df = df.sort_values(by=["Country Name", "Time"], ascending=True)

# %%
df.head()
# Out:
#     Time Time Code Country Name Country Code
# 0   1960    YR1960  Afghanistan          AFG  \
# 33  1961    YR1961  Afghanistan          AFG
# 34  1962    YR1962  Afghanistan          AFG
# 35  1963    YR1963  Afghanistan          AFG
# 37  1964    YR1964  Afghanistan          AFG
#
#    Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative) [SE.PRM.CUAT.FE.ZS]
# 0                                                                                                                     ..  \
# 33                                                                                                                   NaN
# 34                                                                                                                   NaN
# 35                                                                                                                   NaN
# ...

# %%
df.to_excel('../mansoor/update_2.xlsx', index=False)
