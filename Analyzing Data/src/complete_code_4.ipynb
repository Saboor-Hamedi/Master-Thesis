# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../data_processed/education.xlsx')

# %%
df.shape
# Out:
# (74342, 9)

# %%
# df['sex'] = ''

# %%
# df.loc[df['gender'] == 'female', 'sex'] = 0
# df.loc[df['gender'] == 'male', 'sex'] = 1

# %%
df.shape
# Out:
# (74342, 9)

# %%
X = df[['sex']]  
y = df['label']  
# Add a constant term to the predictor variables
X = sm.add_constant(X)
# Fit the logistic regression model
model = sm.Logit(y, X).fit()
# Print the summary
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 6
#       4 X = sm.add_constant(X)
#       5 # Fit the logistic regression model
# ----> 6 model = sm.Logit(y, X).fit()
#       7 # Print the summary
#       8 print(model.summary())
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\discrete\discrete_model.py:465, in BinaryModel.__init__(self, endog, exog, check_rank, **kwargs)
#     463 if not issubclass(self.__class__, MultinomialModel):
#     464     if not np.all((self.endog >= 0) & (self.endog <= 1)):
# --> 465         raise ValueError("endog must be in the unit interval.")
#     467     if (not self._continuous_ok and
#     468             np.any(self.endog != np.round(self.endog))):
#     469         raise ValueError("endog must be binary, either 0 or 1")
#
# ValueError: endog must be in the unit interval.

# %%
const = model.params['const']
sex = model.params['sex']
x_min = df['sex'].min()
x_max = df['sex'].max()
x = np.linspace(x_min, x_max, 100)
y = 1 / (1 + np.exp(-const - sex * x))
plt.plot(x, y)
plt.xlabel('Sex')
plt.ylabel('Probability')
plt.title('Logistic Regression Curve')
plt.show()

# %%
# Out:
# (74342, 9)

# %%
# df.to_excel('../data_processed/sentiment_education.xlsx', index=False)
